# %% [markdown]
# # Исследование надежности заемщиков

# %% [markdown]
# ## Описание проекта
# Каждый банк производит оценку заемщиков для определения аккуратности/пунктуальности в погашении задолженности, эта оценка называется скоринг. <br>
# Скоринг – используемая банками система оценки клиентов, в основе которой заложены статистические методы. Как правило, это компьютерная программа, куда вводятся данные потенциального заемщика. В ответ выдается результат – стоит ли предоставлять ему кредит. Название скоринг происходит от английского слова score, то есть «счет».
#
# Заказчик — кредитный отдел банка. Нужно разобраться, влияет ли семейное положение и количество детей клиента на факт погашения кредита в срок. Входные данные от банка — статистика о платёжеспособности клиентов.
# Результаты исследования будут учтены при построении модели кредитного скоринга — специальной системы, которая оценивает способность потенциального заёмщика вернуть кредит банку.
#
# ## Цель
# Необходимо разобраться, влияет ли семейное положение и количество детей клиента на факт погашения кредита в срок.
# Результаты исследования будут учтены при построении модели кредитного скоринга — специальной системы, которая оценивает способность потенциального заёмщика вернуть кредит банку.
#
#
# ## Описание данных
# - `'children'` — количество детей в семье
# - `'days_employed`' — общий трудовой стаж в днях
# - `'dob_years`' — возраст клиента в годах
# - `'education`' — уровень образования клиента
# - `'education_id`' — идентификатор уровня образования
# - `'family_status`' — семейное положение
# - `'family_status_id`' — идентификатор семейного положения
# - `'gender`' — пол клиента
# - `'income_type`' — тип занятости
# - `'debt`' — имел ли задолженность по возврату кредитов
# - `'total_income`' — ежемесячный доход
# - `'purpose`' — цель получения кредита
#
# ## План работы
# * Откройте таблицу и изучите общую информацию о данных.
# * Самостоятельно изучаем DataFrame.
# * Предобработка данных.
# * Исследуйте данные и ответьте на вопросы.
# * Общий вывод.

# %% [markdown]
# Во второй части проекта вы выполните шаги 3 и 4. Их вручную проверит ревьюер.
# Чтобы вам не пришлось писать код заново для шагов 1 и 2, мы добавили авторские решения в ячейки с кодом.

# %% [markdown]
# ## Откройте таблицу и изучите общую информацию о данных

# %% [markdown]
# **Задание 1. Импортируйте библиотеку pandas. Считайте данные из csv-файла в датафрейм и сохраните в переменную `data`. Путь к файлу:**
#
# `/datasets/data.csv`

# %%
import pandas as pd

try:
    data = pd.read_csv('/datasets/data.csv')
except:
    data = pd.read_csv('E:\WORK\Образование\Аналитик данных\Dataset\Dataset\\Data_sprint4.csv')

# %%
data1 = data.copy(deep=True)

# %% [markdown]
# **Задание 2. Выведите первые 20 строчек датафрейма `data` на экран.**

# %%
data.head(20)
# Out:
#     children  days_employed  dob_years            education  education_id  \
# 0          1   -8437.673028         42               высшее             0
# 1          1   -4024.803754         36              среднее             1
# 2          0   -5623.422610         33              Среднее             1
# 3          3   -4124.747207         32              среднее             1
# 4          0  340266.072047         53              среднее             1
# 5          0    -926.185831         27               высшее             0
# 6          0   -2879.202052         43               высшее             0
# 7          0    -152.779569         50              СРЕДНЕЕ             1
# 8          2   -6929.865299         35               ВЫСШЕЕ             0
# 9          0   -2188.756445         41              среднее             1
# 10         2   -4171.483647         36               высшее             0
# 11         0    -792.701887         40              среднее             1
# ...

# %% [markdown]
# **Задание 3. Выведите основную информацию о датафрейме с помощью метода `info()`.**

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21525 entries, 0 to 21524
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   children          21525 non-null  int64
#  1   days_employed     19351 non-null  float64
#  2   dob_years         21525 non-null  int64
#  3   education         21525 non-null  object
#  4   education_id      21525 non-null  int64
#  5   family_status     21525 non-null  object
#  6   family_status_id  21525 non-null  int64
#  7   gender            21525 non-null  object
#  8   income_type       21525 non-null  object
#  9   debt              21525 non-null  int64
#  10  total_income      19351 non-null  float64
#  11  purpose           21525 non-null  object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 2.0+ MB

# %% [markdown]
# ## Самостоятельно изучаем DataFrame

# %%
def data_analis(data=data, lenght=100, text=False):
    """
    Функция для первичного анализа DataFrame и формирования описательной части в Jupyter
    Передаваемые параметры: data - наш DataFrame, lenght - максимальное кол-во уникальных значений в столбце, text - надо ли формировать описательную часть
    
    """
    print('=====================================================================================================================')
    print('Анализ DataFrame')
    print('=====================================================================================================================')
    print('Этап 1. Первичный анализ.')
    print('=====================================================================================================================')
    display(data.sample(5, random_state =27))
    display(data.describe(include='all'))
    data.info()
    print('==================')
    print('Названия стобцов.')
    print('==================')
    print(data.columns)
    print('==================')
    print('Явные пропуски.')
    print('==================')
    print(data.isna().mean())
    print('==================')
    print('Явные дубликаты.')
    print('==================')
    print(data.duplicated().sum())
    print('==================')
    for i in data.columns:
        if len(data[i].unique()) <= lenght:
            print('======================================================')
            print('Уникальные значения и их кол-во в столбце:', i)
            print('======================================================')
            print(data.sort_values(by=i).groupby(i)[i].count())
    print('======================================================')
    print('Основные параметры числовых значений')
    print('======================================================')
    display(data.describe())
    if text:
        print('\n\n\n')
        print('Таблица для оформления анализа даннных DF.')
        print('### Анализ качества полученных данных.')
        print('В DataFrame:\n<br>- столбцов: ', len(data.columns), '\n<br>- строк: ', len(data), '\n<br>- явных дубликатов: ', data.duplicated().sum(), '\n<br>- доля пропусков в столбцах:\n<br>', data.isna().mean()[data.isna().mean() != 0],'\n<br>', sep='',end='')
        print('- название столбцов:\n', sep='',end='')
        for i in data.columns:
            print('<br>|', i,'|', sep='', end='')
        print('\n\nПроанализируем качество данных в столбцах:')
        for i in data.columns:
            x="'"
            print('- `', x, i, x, '`: Название столбца: правильное/не правильное. Значение: . Проблемы: . Наблюденние: . Рекомендации: .', sep='')

# %%
data_analis(data, text=True)
# Out:
# ...
# Анализ DataFrame
# ...
# Этап 1. Первичный анализ.
# ...
#        children  days_employed  dob_years education  education_id  \
# 1018          1  356170.475243         64   среднее             1
# 11876         0  396541.413988         72    высшее             0
# 2783          1   -1702.357343         49   среднее             1
# 8913          2   -1948.471496         37   среднее             1
# 5781          0    -628.568068         23    высшее             0
#
#                family_status  family_status_id gender  income_type  debt  \
# 1018          вдовец / вдова                 2      F    пенсионер     0
# 11876        женат / замужем                 0      M    пенсионер     0
# 2783         женат / замужем                 0      M    сотрудник     0
# 8913        гражданский брак                 1      M  госслужащий     0
# 5781   Не женат / не замужем                 4      F    компаньон     0
#
#         total_income                           purpose
# ...

# %% [markdown]
# ### Анализ качества полученных данных.
# В DataFrame:
# <br>- столбцов: 12
# <br>- строк: 21525
# <br>- явных дубликатов: 54
# <br>- доля пропущеных значенний в столбцах:
# <br>days_employed    0.100999
# total_income     0.100999
# dtype: float64
# <br>- Название столбцов:
# <br>|children|<br>|days_employed|<br>|dob_years|<br>|education|<br>|education_id|<br>|family_status|<br>|family_status_id|<br>|gender|<br>|income_type|<br>|debt|<br>|total_income|<br>|purpose|
#
# Проанализируем качество данных в столбцах:
# - `'children'`: Название столбца: правильное. Значение: количество детей в семье. Проблемы: есть значенние -1 (47 шт.) и значение 20 (76 шт.), вероятно это 1 и 2. Наблюдение: У 75% не более 1 ребенка. Рекомендации: 1) т.к. коолчиество ошибок не велико, можно строки дроопнуть; 2) дать рекомендацию разработчику формы, запретить ввод отрицательных величин и дать алерт при введении значений больше 4, чтобы специалист обратил на это внимание.
# - `'days_employed'`: Название столбца: правильное. Значение: общий трудовой стаж в днях. Проблемы: 1) есть отрицательные значения есть очень большие значения, переводятся как дни работы, но если перевести в года, то столько не живут; 2) есть пропуски. Рекомендации: проверить неправдоподобные значения и перевести в положительные, разобраться с пропусками.
# - `'dob_years'`: Название столбца: правильное. Значение: возраст клиента в годах. Проблемы: есть нулевые значения (101 шт.). Наблюденние: максимальноое кол-во заемщиков в возрасте 26-60 лет. Рекомендации: 1) 0-ые значения можно не удалять т.к. роль этих данных не существенна; 2) дать рекомендацию разработчику формы, ввести порог на минимальный возраст, выдавать алерт, если возраст больше 70.
# - `'education'`: Название столбца: правильное. Значение: уровень образования клиента. Проблемы: 15 уникальных значенний, значения дублируются, т.к. находятся в разном регистре. Наблюденние: больше всего заемщиков с средним обрразованиеем, меньше всего с ученой степенью. Рекомендации: 1) привести к одному регистру; 2) дать рекомендацию разработчику формы, данные по образование через выпадающий список.
# - `'education_id'`: Название столбца: правильное. Значение:  идентификатор уровня образования (например: 0 - высшее, 1 - среднее). Проблемы: нет. Наблюденние: больше всего заемщиков с средним образованием, меньше всего с учееной степенью. Рекомендации: нет.
# - `'family_status'`: Название столбца: правильное. Значение: семейное положение. Проблемы: разный регистр. Наблюденние: . Рекомендации: 1) привести к одному регистру; 2) дать рекомендацию разработчику формы, данные по семейнному положению через выпадающий список.
# - `'family_status_id'`: Название столбца: правильное. Значение: идентификатор семейного положения (например: 0 - женат / замужем, 1 - гражданский брак). Проблемы: нет. Наблюденние: 1) значения могут кочевать из одного типа в другой или могут быть условнно одинаковыми (например вдовец, не женат, гражданский брак), но они относятся к разным группам что может влиять на скоринг; 2) больше всегго заемщиков среди женатых, меньше среди вдовцов. Рекомендации: уточнить, как проверяется семейный статус, насколько ему можно верить.
# - `'gender'`: Название столбца: правильное. Значение: пол клиента. Проблемы: 1) верхний регистр; 2) есть одно знначение с нееизвестным полом. Наблюденние: среди заемщиков в 2 раза больше женщин. Рекомендации: 1) привести к нижнему регистру, данные с непонятнным полом можно оставить т.к. данная информация не критичнна; 2) дать рекомендацию разработчику формы, данные по полу получать через выпадающий список.
# - `'income_type'`: Название столбца: правильное. Значение: тип занятости. Проблемы: не понятно как проверяются данные, не мигрируют ли типы между собой, практически нулевое кол-во значний у безработный/в декрете/предприниматель/студент, не понятно кто такие компаньены и как вообще проверяются данные, насколько им можно верить. Наблюденние: больше всего заемщиков в категории сотрудник, меньше всего в госслужащий, вероятно из-за разницы в их общем кол-ве. Рекомендации: 1) убрать не влияющие на статистику данные; 2) дать рекомендацию разработчику формы, данные по типу дохода получать через выпадающий список.
# - `'debt'`: Название столбца: правильное. Значение: имел ли задолженность по возврату кредитов. Проблемы: нет. Наблюденние: значений с статусом 0 болше чем 1 в 10 раз. Рекомендации: нет.
# - `'total_income'`: Название столбца: правильное. Значение: ежемесячный доход. Проблемы: данные вещественные и есть пропуски. Наблюденние: 75% людей зарабатываю до 200 т.р. в месяц. Рекомендации: привести данные к целым, разобраться с пропусками.
# - `'purpose'`: Название столбца: правильное. Значение: цель получения кредита. Проблемы: 38 уникальных значениий, значения в одном регистре, но нет жесткой формы, необходимо группировать. Наблюденние: необходимо группировать. Рекомендации: 1) группировать данные; 2) дать рекомендацию разработчику формы, данные по цели кредита получать через выпадающий список.

# %% [markdown]
# ## Предобработка данных

# %% [markdown]
# ### Удаление пропусков

# %% [markdown]
# **Задание 4. Выведите количество пропущенных значений для каждого столбца. Используйте комбинацию двух методов.**

# %%
data.isna().sum()
# Out:
# children               0
# days_employed       2174
# dob_years              0
# education              0
# education_id           0
# family_status          0
# family_status_id       0
# gender                 0
# income_type            0
# debt                   0
# total_income        2174
# purpose                0
# dtype: int64

# %% [markdown]
# **Задание 5. В двух столбцах есть пропущенные значения. Один из них — `days_employed`. Пропуски в этом столбце вы обработаете на следующем этапе. Другой столбец с пропущенными значениями — `total_income` — хранит данные о доходах. На сумму дохода сильнее всего влияет тип занятости, поэтому заполнить пропуски в этом столбце нужно медианным значением по каждому типу из столбца `income_type`. Например, у человека с типом занятости `сотрудник` пропуск в столбце `total_income` должен быть заполнен медианным доходом среди всех записей с тем же типом.**

# %%
for t in data['income_type'].unique():
    data.loc[(data['income_type'] == t) & (data['total_income'].isna()), 'total_income'] = \
    data.loc[(data['income_type'] == t) & (data['total_income'].isna() == False), 'total_income'].median()

# %% [markdown]
# ### Обработка аномальных значений

# %% [markdown]
# **Задание 6. В данных могут встречаться артефакты (аномалии) — значения, которые не отражают действительность и появились по какой-то ошибке. таким артефактом будет отрицательное количество дней трудового стажа в столбце `days_employed`. Для реальных данных это нормально. Обработайте значения в этом столбце: замените все отрицательные значения положительными с помощью метода `abs()`.**

# %%
data['days_employed'] = data['days_employed'].abs()

# %% [markdown]
# **Задание 7. Для каждого типа занятости выведите медианное значение трудового стажа `days_employed` в днях.**

# %%
data.groupby('income_type')['days_employed'].agg('median')
# Out:
# income_type
# безработный        366413.652744
# в декрете            3296.759962
# госслужащий          2689.368353
# компаньон            1547.382223
# пенсионер          365213.306266
# предприниматель       520.848083
# сотрудник            1574.202821
# студент               578.751554
# Name: days_employed, dtype: float64

# %% [markdown]
# У двух типов (безработные и пенсионеры) получатся аномально большие значения. Исправить такие значения сложно, поэтому оставьте их как есть. Тем более этот столбец не понадобится вам для исследования.

# %% [markdown]
# Уберем одну запись у которой gender XNA.

# %%
data = data.loc[data['gender'] != 'XNA']

# %% [markdown]
# Уберем 100 записей с возрастом 0.

# %%
data = data.loc[data['dob_years'] != 0]

# %% [markdown]
# **Задание 8. Выведите перечень уникальных значений столбца `children`.**

# %%
data['children'].unique()
# Out:
# array([ 1,  0,  3,  2, -1,  4, 20,  5], dtype=int64)

# %% [markdown]
# **Задание 9. В столбце `children` есть два аномальных значения. Удалите строки, в которых встречаются такие аномальные значения из датафрейма `data`.**

# %%
data = data[(data['children'] != -1) & (data['children'] != 20)]

# %% [markdown]
# **Задание 10. Ещё раз выведите перечень уникальных значений столбца `children`, чтобы убедиться, что артефакты удалены.**

# %%
data['children'].unique()
# Out:
# array([1, 0, 3, 2, 4, 5], dtype=int64)

# %% [markdown]
# ### Удаление пропусков (продолжение)

# %% [markdown]
# **Задание 11. Заполните пропуски в столбце `days_employed` медианными значениями по каждого типа занятости `income_type`.**

# %%
for t in data['income_type'].unique():
    data.loc[(data['income_type'] == t) & (data['days_employed'].isna()), 'days_employed'] = \
    data.loc[(data['income_type'] == t) & (data['days_employed'].isna() == False), 'days_employed'].median()

# %% [markdown]
# **Задание 12. Убедитесь, что все пропуски заполнены. Проверьте себя и ещё раз выведите количество пропущенных значений для каждого столбца с помощью двух методов.**

# %%
data.isna().sum()
# Out:
# children            0
# days_employed       0
# dob_years           0
# education           0
# education_id        0
# family_status       0
# family_status_id    0
# gender              0
# income_type         0
# debt                0
# total_income        0
# purpose             0
# dtype: int64

# %% [markdown]
# ### Изменение типов данных

# %% [markdown]
# **Задание 13. Замените вещественный тип данных в столбце `total_income` на целочисленный с помощью метода `astype()`.**

# %%
data['total_income'] = data['total_income'].astype(int)

# %% [markdown]
# ### Обработка дубликатов

# %% [markdown]
# **Задание 14. Обработайте неявные дубликаты в столбце `education`. В этом столбце есть одни и те же значения, но записанные по-разному: с использованием заглавных и строчных букв. Приведите их к нижнему регистру. Проверьте остальные столбцы.**

# %%
for i in data.columns:
    if data[i].dtypes == 'object':
        data[i] = data[i].str.lower()

# %% [markdown]
# **Задание 15. Выведите на экран количество строк-дубликатов в данных. Если такие строки присутствуют, удалите их.**

# %%
data.duplicated().sum()
# Out:
# 71

# %%
data = data.drop_duplicates()

# %% [markdown]
# ### Категоризация данных

# %% [markdown]
# **Задание 16. На основании диапазонов, указанных ниже, создайте в датафрейме `data` столбец `total_income_category` с категориями:**
#
# - 0–30000 — `'E'`;
# - 30001–50000 — `'D'`;
# - 50001–200000 — `'C'`;
# - 200001–1000000 — `'B'`;
# - 1000001 и выше — `'A'`.
#
#
# **Например, кредитополучателю с доходом 25000 нужно назначить категорию `'E'`, а клиенту, получающему 235000, — `'B'`. Используйте собственную функцию с именем `categorize_income()` и метод `apply()`.**

# %%
def categorize_income(income):
    try:
        if 0 <= income <= 30000:
            return 'E'
        elif 30001 <= income <= 50000:
            return 'D'
        elif 50001 <= income <= 200000:
            return 'C'
        elif 200001 <= income <= 1000000:
            return 'B'
        elif income >= 1000001:
            return 'A'
    except:
        pass

# %%
data['total_income_category'] = data['total_income'].apply(categorize_income)

# %% [markdown]
# **Задание 17. Выведите на экран перечень уникальных целей взятия кредита из столбца `purpose`.**

# %%
data['purpose'].unique()
# Out:
# array(['покупка жилья', 'приобретение автомобиля',
#        'дополнительное образование', 'сыграть свадьбу',
#        'операции с жильем', 'образование', 'на проведение свадьбы',
#        'покупка жилья для семьи', 'покупка недвижимости',
#        'покупка коммерческой недвижимости', 'покупка жилой недвижимости',
#        'строительство собственной недвижимости', 'недвижимость',
#        'строительство недвижимости', 'на покупку подержанного автомобиля',
#        'на покупку своего автомобиля',
#        'операции с коммерческой недвижимостью',
#        'строительство жилой недвижимости', 'жилье',
#        'операции со своей недвижимостью', 'автомобили',
#        'заняться образованием', 'сделка с подержанным автомобилем',
#        'получение образования', 'автомобиль', 'свадьба',
#        'получение дополнительного образования', 'покупка своего жилья',
#        'операции с недвижимостью', 'получение высшего образования',
#        'свой автомобиль', 'сделка с автомобилем',
# ...

# %% [markdown]
# **Задание 18. Создайте функцию, которая на основании данных из столбца `purpose` сформирует новый столбец `purpose_category`, в который войдут следующие категории:**
#
# - `'операции с автомобилем'`,
# - `'операции с недвижимостью'`,
# - `'проведение свадьбы'`,
# - `'получение образования'`.
#
# **Например, если в столбце `purpose` находится подстрока `'на покупку автомобиля'`, то в столбце `purpose_category` должна появиться строка `'операции с автомобилем'`.**
#
# **Используйте собственную функцию с именем `categorize_purpose()` и метод `apply()`. Изучите данные в столбце `purpose` и определите, какие подстроки помогут вам правильно определить категорию.**

# %%
def categorize_purpose(row):
    try:
        if 'автом' in row:
            return 'операции с автомобилем'
        elif 'жил' in row or 'недвиж' in row:
            return 'операции с недвижимостью'
        elif 'свад' in row:
            return 'проведение свадьбы'
        elif 'образов' in row:
            return 'получение образования'
    except:
        return 'нет категории'

# %%
data['purpose_category'] = data['purpose'].apply(categorize_purpose)

# %% [markdown]
# ### Шаг 3. Исследуйте данные и ответьте на вопросы

# %% [markdown]
# #### 3.1 Есть ли зависимость между количеством детей и возвратом кредита в срок?

# %%
print('Всего заемщиков:', len(data),'. Заемщиков у которых менее 3-ех детей:{:.2%}'.format
      (len(data[data['children'] < 3])/len(data)), sep='')
display(data[data['children'] < 3].pivot_table(index=['children'], values='debt', aggfunc=['mean','count']))
# Out:
# Всего заемщиков:21230. Заемщиков у которых менее 3-ех детей:98.22%
#               mean  count
#               debt   debt
# children
# 0         0.075458  14021
# 1         0.092028   4792
# 2         0.095145   2039

# %% [markdown]
# **Вывод:** Т.к. заемщики у которых более 3-ех детей составляют всего лишь ~2% от всех заемщиков, то считаем такую выборку не репрезентативной, соответственно ей можно пренебречь. Самая многочисленная группа заемщиков не имеет детей, у этой группы самый маленький процент невозврата, разница с остальными группами, среди тех кто не оплатил вовремя из этой группы, составляет до 20% и до 2% из общего количества в группах. <br>Таким образом, исходя из имеющихся данных, можно сказать, что прослеживается зависимость между количеством детей и вероятностью возврата кредита в срок, а именно: **люди с меньшим кол-ом детей чаще возвращают кредит в срок.** Т.к. группы существенно отличаются по количеству, есть подозрение, что если бы заемщиков с детьми было бы больше, то результаты были бы схожи.

# %% [markdown]
# #### 3.2 Есть ли зависимость между семейным положением и возвратом кредита в срок?

# %%
display(data.pivot_table(index='family_status', values='debt', aggfunc=['mean','count']).sort_values(by=( 'mean', 'debt')))
# Out:
#                            mean  count
#                            debt   debt
# family_status
# вдовец / вдова         0.065539    946
# в разводе              0.071247   1179
# женат / замужем        0.075575  12213
# гражданский брак       0.093142   4112
# не женат / не замужем  0.097842   2780

# %% [markdown]
# **Вывод:** Самая многочисленная группа заемщиков находится в браке, у этой группы средний процент невозврата. Самый низкий процент вдов(цов) разница с остальными группами, среди тех кто не оплатил вовремя из этой группы, составляет до 33% и до 3% из общего количества в группах. <br>Таким образом, исходя из имеющихся данных, можно сказать, что прослеживается зависимость между семейным положением и вероятностью возврата кредита в срок, а именно: **люди которые были или находятся в браке чаще возвращают кредит в срок.** Т.к. группы существенно отличаются по количеству, основное влияние на общее кол-во невозвратов в срок оказывает самая многочисленная группа.

# %% [markdown]
# #### 3.3 Есть ли зависимость между уровнем дохода и возвратом кредита в срок?

# %%
display(data.pivot_table(index='total_income_category', values='debt', aggfunc=['mean','count']).sort_values(by=('mean', 'debt')))
# Out:
#                            mean  count
#                            debt   debt
# total_income_category
# D                      0.060519    347
# B                      0.070784   4987
# A                      0.080000     25
# C                      0.084926  15849
# E                      0.090909     22

# %%
display(data[(data['total_income_category'] != 'E') & (data['total_income_category'] != 'A') & (data['total_income_category'] != 'D')].pivot_table(index='total_income_category', values='debt', aggfunc=['mean','count']).sort_values(by=('mean', 'debt')))
# Out:
#                            mean  count
#                            debt   debt
# total_income_category
# B                      0.070784   4987
# C                      0.084926  15849

# %% [markdown]
# **Вывод:** Из-за количества, группами E,A,D можно пренебречь. Самый низкий процент не возврата в срок у людей из группы B, разница с остальными группами, среди тех кто не оплатил вовремя из этой группы, составляет до 17% и до 1% из общего количества в группах.
# Таким образом, исходя из имеющихся данных, можно сказать, что прослеживается зависимость между ежемесячным доходом и вероятностью возврата кредита в срок, а именно: **люди с большим достатком чаще возвращают кредит в срок.** Т.к. группы существенно отличаются по количеству, основное влияние на общее кол-во невозвратов в срок оказывает самая многочисленная группа.

# %% [markdown]
# #### 3.4 Как разные цели кредита влияют на его возврат в срок?

# %%
display(data.pivot_table(index='purpose_category', values='debt', aggfunc=['mean','count']).sort_values(by=('mean', 'debt')))
# Out:
#                               mean  count
#                               debt   debt
# purpose_category
# операции с недвижимостью  0.072596  10703
# проведение свадьбы        0.078730   2299
# получение образования     0.092947   3970
# операции с автомобилем    0.093236   4258

# %% [markdown]
# **Вывод:** Самая многочисленная группа заемщиков берет кредит на недвижимость, у этой группы самый низкий процент не возврата кредита в срок, разница с остальными группами, среди тех кто не оплатил вовремя из этой группы, составляет до 22% и до 3% из общего количества в группах. <br>Таким образом, исходя из имеющихся данных, можно сказать, что прослеживается зависимость между целью кредита и вероятностью возврата кредита в срок, а именно: **люди, которые берут кредит на более глобальные цели (жилье, семья) чаще возвращают кредит в срок.**  Т.к. группы существенно отличаются по количеству, основное влияние на общее кол-во невозвратов в срок оказывает самая многочисленная группа.

# %% [markdown]
# ### Проверка других зависимостей

# %% [markdown]
# #### 3.5 Как образование влияет на возврат кредита в срок?

# %%
display(data.pivot_table(index='education', values='debt', aggfunc=['mean','count']).sort_values(by=('mean', 'debt')))
# Out:
#                          mean  count
#                          debt   debt
# education
# ученая степень       0.000000      6
# высшее               0.053351   5192
# среднее              0.089795  15012
# неоконченное высшее  0.092141    738
# начальное            0.109929    282

# %% [markdown]
# **Вывод:** Из-за количества, группой с ученой степенью и начальным образованием можно пренебречь. Самая многочисленная группа заемщиков имеет среднее образование, у этой группы средний процент невозврата кредита в срок. Самый низкий процент невозврата в срок у людей с высшим образованием, разница с остальными группами, среди тех, кто не оплатил вовремя из этой группы, составляет до 42% и до 4% из общего количества в группах. <br>Таким образом, исходя из имеющихся данных, можно сказать, что прослеживается зависимость между образованием заемщика и вероятностью возврата кредита в срок, а именно: **более образованные люди чаще возвращают кредит в срок.** Т.к. группы существенно отличаются по количеству, основное влияние на общее кол-во невозвратов в срок оказывает самая многочисленная группа.

# %% [markdown]
# #### 3.6 Как возраст влияет на возврат кредита в срок?

# %%
display(data.pivot_table(index='dob_years' ,values='debt',\
        aggfunc=['mean','count']).sort_values(by=('mean', 'debt')))
# Out:
#                mean count
#                debt  debt
# dob_years
# 75         0.000000     1
# 74         0.000000     6
# 73         0.000000     8
# 71         0.017857    56
# 61         0.028409   352
# 66         0.043956   182
# 63         0.044776   268
# 70         0.046154    65
# 64         0.046512   258
# 69         0.048193    83
# 62         0.051873   347
# 55         0.052154   441
# 58         0.052863   454
# 67         0.053892   167
# 51         0.054054   444
# 52         0.057971   483
# 60         0.058981   373
# 72         0.060606    33
# 49         0.061386   505
# 48         0.061798   534
# 54         0.065539   473
# 57         0.066225   453
# 56         0.066946   478
# 59         0.068182   440
# 42         0.071066   591
# 19         0.071429    14
# 65         0.072539   193
# 44         0.075786   541
# 53         0.076586   457
# 35         0.076672   613
# 39         0.077058   571
# 47         0.077568   477
# 36         0.077899   552
# ...

# %% [markdown]
# Зависимость есть но таблица плохочитаемая, необходимо категоризировать данные. Разобьем всех клиентов на поколения.

# %%
for i in data['dob_years'].unique():    
    if 1944 > 2022 - i >= 1925:
        data.loc[data['dob_years'] == i, 'generation'] = 'молчаливое'
    if 1967 > 2022 - i >= 1944:
        data.loc[data['dob_years'] == i, 'generation'] = 'бэби бумеры'
    if 1984 > 2022 - i >= 1967:
        data.loc[data['dob_years'] == i, 'generation'] = 'X'
    if 2000 > 2022 - i >= 1984:
        data.loc[data['dob_years'] == i, 'generation'] = 'Y'
    if 2015 > 2022 - i >= 2000:
        data.loc[data['dob_years'] == i, 'generation'] = 'Z'
    
display(data.pivot_table(index='generation' ,values='debt',\
        aggfunc=['mean','count']).sort_values(by=('mean', 'debt')))
# Out:
#                  mean count
#                  debt  debt
# generation
# бэби бумеры  0.055375  4316
# X            0.072685  8695
# Y            0.102913  7861
# Z            0.122905   358

# %% [markdown]
# **Вывод:** Из-за количества, группой с людьми поколения Z можно пренебречь. Самая многочисленная группа заемщиков относится к поколению X, у этой группы средний процент невозврата кредита в срок. Самый низкий процент не возврата в срок у поколения беби бумеров, разница с остальными группами, среди тех кто не оплатил вовремя из этой группы, составляет до 46% и до 5% из общего количества в группах. <br> Таким образом, исходя из имеющихся данных, можно сказать, что прослеживается зависимость между возрастом и вероятностью возврата кредита в срок, а именно: **люди в возрасте существенно чаще возвращают кредит в срок.**

# %% [markdown]
# #### 3.7 Как тип занятости влияет на возврат кредита в срок?

# %%
display(data.pivot_table(index='income_type' ,values='debt',\
        aggfunc=['mean','count']).sort_values(by=('mean', 'debt')))
# Out:
#                      mean  count
#                      debt   debt
# income_type
# предприниматель  0.000000      2
# студент          0.000000      1
# пенсионер        0.056698   3792
# госслужащий      0.059516   1445
# компаньон        0.074214   5026
# сотрудник        0.095612  10961
# безработный      0.500000      2
# в декрете        1.000000      1

# %% [markdown]
# **Вывод:** Из-за количества, группой предпринимателей, студентов, безработных и находящихся в декрете можно пренебречь. Самая многочисленная группа заемщиков - сотрудники, у этой группы самый высокий процент невозврата кредита в срок. Самый низкий процент невозврата в срок у пенсионеров, разница с остальными группами, среди тех, кто не оплатил вовремя из этой группы, составляет до 41% и до 4% из общего количества в группах. <br>Таким образом, исходя из имеющихся данных, можно сказать, что прослеживается зависимость между типом занятости и вероятностью возврата кредита в срок, а именно: **люди имеющие постоянный, гарантированный доход от государства чаще возвращают кредит в срок.** Т.к. группы существенно отличаются по количеству, основное влияние на общее кол-во невозвратов в срок оказывает самая многочисленная группа.

# %% [markdown]
# #### 3.9 Как пол влияет на возврат кредита в срок?

# %%
display(data.pivot_table(index='gender' ,values='debt',\
        aggfunc=['mean','count']).sort_values(by=('mean', 'debt')))
# Out:
#             mean  count
#             debt   debt
# gender
# f       0.070180  14021
# m       0.102649   7209

# %% [markdown]
# **Вывод:** Самая многочисленная группа заемщиков - женщины (больше в 2 раза). Самый низкий процент невозврата в срок у женщин, разница с остальными группами, среди тех, кто не оплатил вовремя из этой группы, составляет до 32% и до 3% из общего количества в группах. <br>Таким образом, исходя из имеющихся данных, можно сказать, что прослеживается зависимость между полом заемщика и вероятностью возврата кредита в срок, а именно: **женщины чаще возвращают кредит в срок.** Т.к. группы существенно отличаются по количеству, основное влияние на общее кол-во невозвратов в срок оказывает самая многочисленная группа.

# %% [markdown]
# #### 3.5 Приведите возможные причины появления пропусков в исходных данных.

# %%
print('Количество пропусков в столбце days_employed:', data1['days_employed'].isna().sum(),'\nв столбце total_income:',data1['days_employed'].isna().sum(), 
      '\nв двух столбцах одновременно:', len(data1[(data1['days_employed'].isna()) & (data1['total_income'].isna())]),
      '\nв двух столбцах одновременно и при значении в debt=0:', len(data1[(data1['days_employed'].isna()) & (data1['total_income'].isna()) & (data1['debt'] == 0)]))
display(data1[(data1['days_employed'].isna()) & (data1['total_income'].isna() & (data1['debt'] == 1))].sample(10, random_state=27))
# Out:
# Количество пропусков в столбце days_employed: 2174
# в столбце total_income: 2174
# в двух столбцах одновременно: 2174
# в двух столбцах одновременно и при значении в debt=0: 2004
#        children  days_employed  dob_years education  education_id  \
# 20314         0            NaN         27   среднее             1
# 8301          0            NaN         36    высшее             0
# 19251         0            NaN         38   среднее             1
# 16394         2            NaN         36   среднее             1
# 9153          0            NaN         57   среднее             1
# 15592         1            NaN         38   среднее             1
# 18556         1            NaN         25   среднее             1
# 20354         0            NaN         59   среднее             1
# 10563         0            NaN         72   Среднее             1
# 3888          2            NaN         34   СРЕДНЕЕ             1
#
# ...

# %%
for i in data1.columns:
    print(i, ':', data1[(data1['days_employed'].isna()) & (data1['total_income'].isna())][i].unique())
# Out:
# children : [ 0  1  2 -1  3  4 20  5]
# days_employed : [nan]
# dob_years : [65 41 63 50 54 21 52 32 35 34 44 47 46 29 27 39 62 55 26 30 31 23 58 60
#  40 66 33 56 69 59 57 45 53 48 51 37 43 24 28 67 64 25 49 42 61 36 70 38
#  20  0 68 19 22 71 72 73]
# education : ['среднее' 'высшее' 'СРЕДНЕЕ' 'неоконченное высшее' 'Среднее'
#  'Неоконченное высшее' 'Высшее' 'НЕОКОНЧЕННОЕ ВЫСШЕЕ' 'начальное' 'ВЫСШЕЕ'
#  'Начальное' 'НАЧАЛЬНОЕ']
# education_id : [1 0 2 3]
# family_status : ['гражданский брак' 'женат / замужем' 'Не женат / не замужем'
#  'вдовец / вдова' 'в разводе']
# family_status_id : [1 0 4 2 3]
# gender : ['M' 'F']
# income_type : ['пенсионер' 'госслужащий' 'компаньон' 'сотрудник' 'предприниматель']
# debt : [0 1]
# total_income : [nan]
# purpose : ['сыграть свадьбу' 'образование' 'строительство жилой недвижимости'
#  'сделка с подержанным автомобилем'
#  'операции с коммерческой недвижимостью' 'покупка жилья для семьи' 'жилье'
# ...

# %% [markdown]
# *Ответ:* Пропуски в столбцах `'days_employed'` и `'total_income'` связаны между собой, т.к. они находятся в одних и тех же строках, большинство из них имеют в столбце `'debt'` 0, что не является аномалией, число не возвратов по разным группам до 10%.<br> Т.к. явной закономерности с другими столбцами нет, вероятно пропуск допущен в одном из столбцов, а во втором столбце система сама сделала пропуск. Скорее всего, некоторые клиенты отказывались называть свой заработок.

# %% [markdown]
# #### 3.6 Объясните, почему заполнить пропуски медианным значением — лучшее решение для количественных переменных.

# %% [markdown]
# *Ответ:* Для получения значений близких к реальным, необходимо отсечь пики, сильно искажающие средние значения и учесть данные с которыми есть корреляция. Поэтому мы брали медианные значения из группы значений соответствующих типу занятости клиента.

# %% [markdown]
# ### Шаг 4: общий вывод.

# %% [markdown]
# В данном исследовании мы работали со следующими данными:
# - `'children'`: Значение: количество детей в семье. В данных обнаружены проблемы: есть значение -1 (47 шт.) и значение 20 (76 шт.), вероятно это 1 и 2.
# - `'days_employed'`: Значение: общий трудовой стаж в днях. В данных обнаружены проблемы: 1) есть отрицательные значения есть очень большие значения, переводятся как дни работы, но если перевести в года, то столько не живут; 2) есть пропуски.
# - `'dob_years'`: Значение: возраст клиента в годах. В данных обнаружены проблемы: есть нулевые значения (101 шт.).
# - `'education'`: Значение: уровень образования клиента. В данных обнаружены проблемы: 15 уникальных значении, значения дублируются, т.к. находятся в разном регистре.
# - `'education_id'`: Значение: идентификатор уровня образования (например: 0 - высшее, 1 - среднее).
# - `'family_status'`: Значение: семейное положение. В данных обнаружены проблемы: разный регистр.
# - `'family_status_id'`: Значение: идентификатор семейного положения. В данных обнаружены проблемы: нет. Наблюдение: 1) значения могут кочевать из одного типа в другой или могут быть условно одинаковыми (например, вдовец, не женат, гражданский брак), но они относятся к разным группам что может влиять на скоринг; 2) больше всего заемщиков среди женатых, меньше среди вдовцов.
# - `'gender'`: Значение: пол клиента. В данных обнаружены проблемы: 1) верхний регистр; 2) есть одно значение с неизвестным полом. Наблюдение: среди заемщиков в 2 раза больше женщин.
# - `'income_type'`: Значение: тип занятости. В данных обнаружены проблемы: не понятно, как проверяются данные, не мигрируют ли типы между собой, практически нулевое кол-во знаний у безработный/в декрете/предприниматель/студент, не понятно кто такие компаньоны и как вообще проверяются данные, насколько им можно верить.
# - `'debt'`: Значение: имел ли задолженность по возврату кредитов.
# - `'total_income'`: Значение: ежемесячный доход. В данных обнаружены проблемы: данные вещественные и есть пропуски.
# - `'purpose'`: Значение: цель получения кредита. В данных обнаружены проблемы: 38 уникальных значении, значения в одном регистре, но нет жесткой формы, необходимо группировать.

# %% [markdown]
# В процессе предобработки, различными методами все обнаруженные в данных проблемы были устранены.

# %% [markdown]
# **Итоги:** <br>
# В данном исследовании мы убедились, что существует зависимость невозврата клиентом кредита в срок от:
# - `количества детей` - **люди с меньшим кол-ом детей чаще возвращают кредит в срок.**
# - `семейного положения` - **люди которые были или находятся в браке чаще возвращают кредит в срок.**
# - `ежемесячный доход` - **люди с большим достатком чаще возвращают кредит в срок.**
# - `цели кредита` - **люди, которые берут кредит на более глобальные цели (жилье, семья) чаще возвращают кредит в срок.**
# - `образования` - **более образованные люди чаще возвращают кредит в срок.**
# - `поколения` - **люди в возрасте существенно чаще возвращают кредит в срок.**
# - `типа занятости` - **люди имеющие постоянный, гарантированный доход от государства чаще возвращают кредит в срок.**
# - `пола` - **женщины чаще возвращают кредит в срок.**
# <br><br>
#
# Для скоринга необходимо придать параметрам веса и добавить в общую формулу. Если бы были данные по невозвратным кредитам, можно было бы уточнить веса, прогнав формулу по существующим данным, отслеживая кол-во невозвратных кредитов. Т.к. просрочка не является убытком для банка.

# %% [markdown]
# ### Рекомендации по сбору данных

# %% [markdown]
# - `'children'`: Рекомендации: запретить ввод отрицательных величин и дать алерт при введении значений больше 4, чтобы специалист обратил на это внимание.
# - `'days_employed'`: Рекомендации: проверить не правдоподобные значения и перевести в положительные, разобраться с пропусками. Как считается стаж?
# - `'dob_years'`: Рекомендации: ввести порог на минимальный возраст, выдавать алерт, если возраст больше 70.
# - `'education'`: Рекомендации: данные по образованию получать через выпадающий список.
# - `'family_status'`: Рекомендации: данные по семейному положению через выпадающий список.
# - `'family_status_id'`: Рекомендации: уточнить, как проверяется семейный статус, насколько ему можно верить.
# - `'gender'`: Рекомендации: данные по полу получать через выпадающий список.
# - `'income_type'`: Рекомендации: данные по типу дохода получать через выпадающий список.
# - `'total_income'`: Рекомендации: уточнить причину появления пропусков.
# - `'purpose'`: Рекомендации: данные по цели кредита получать через выпадающий список.
